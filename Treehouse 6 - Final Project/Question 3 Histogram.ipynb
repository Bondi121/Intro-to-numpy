# %%
import csv
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
from matplotlib.figure import Figure

sns.set_theme(style="whitegrid")

videogames = pd.read_csv('top100videogamesales.csv')
videogames.head(10)
# Out:
#    Rank                       Name  Platform  Year       Genre Publisher  \
# 0     1                 Wii Sports  Nintendo  2006      Sports  Nintendo
# 1     2             Mario Kart Wii  Nintendo  2008      Racing  Nintendo
# 2     3          Wii Sports Resort  Nintendo  2009      Sports  Nintendo
# 3     4      New Super Mario Bros.  Nintendo  2006    Platform  Nintendo
# 4     5                   Wii Play  Nintendo  2006        Misc  Nintendo
# 5     6  New Super Mario Bros. Wii  Nintendo  2009    Platform  Nintendo
# 6     7                 Nintendogs  Nintendo  2005  Simulation  Nintendo
# 7     8              Mario Kart DS  Nintendo  2005      Racing  Nintendo
# 8     9                    Wii Fit  Nintendo  2007      Sports  Nintendo
# 9    10               Wii Fit Plus  Nintendo  2009      Sports  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     15.85     12.88      3.79         3.31         35.82
# 2     15.75     11.01      3.28         2.96         33.00
# 3     11.38      9.23      6.50         2.90         30.01
# 4     14.03      9.20      2.93         2.85         29.02
# 5     14.59      7.06      4.70         2.26         28.62
# 6      9.07     11.00      1.93         2.75         24.76
# 7      9.81      7.57      4.13         1.92         23.42
# 8      8.94      8.03      3.60         2.15         22.72
# 9      9.09      8.59      2.53         1.79         22.00

# %% [markdown]
# ## North American Sales by Genre: Create a pie chart to show the percentage of sales each genre had in the North American market. (Group smaller “slices” together into an “other” category to create an easier to read chart) Detail what is included in the other category. Explain the chart using markdown.

# %%
import csv
import matplotlib.pyplot as plt

input_file = 'top100videogamesales.csv'
plt.figure(figsize=(7.5, 4.25))
plt.style.use('classic')

with open(input_file, 'r') as old_faithful_data:
    eruptions = list(csv.reader(old_faithful_data))
    
eruptions.pop(0)

eruption_times = []

for event in range (0, len(eruptions)-1):
    if eruptions[event][4] == "Action":
        eruption_times.append(float(eruptions[event][10]))
    

plt.subplot(1,1,1)
num_bins=8
plt.hist(eruption_times, num_bins)
plt.title('Old Faithful Eruptions')
plt.xlabel('Length of Eruption (mins)')

plt.show()

# %% [markdown]
# ## Global Sales Distribution for Action Games: Create a histogram to show the global sales distribution for games with Action as the genre. Explain the chart with markdown.

# %%
action_games = videogames[videogames['Genre'] == 'Action']
action_games[['Global_Sales']].plot(kind ='hist', bins=17, figsize=(10,8), color="green", title = 'Action Videogames sales distribution')
# Out:
# <AxesSubplot: title={'center': 'Action Videogames sales distribution'}, ylabel='Frequency'>

# %%
action_games = videogames[videogames['Genre'] == 'Action']
action_games
# Out:
#     Rank                                    Name     Platform  Year   Genre  \
# 11    12                      Grand Theft Auto V  PlayStation  2013  Action
# 12    13           Grand Theft Auto: San Andreas  PlayStation  2004  Action
# 15    16                      Grand Theft Auto V         XBox  2013  Action
# 16    17             Grand Theft Auto: Vice City  PlayStation  2002  Action
# 29    30                    Grand Theft Auto III  PlayStation  2001  Action
# 35    36                      Grand Theft Auto V  PlayStation  2014  Action
# 36    37    Pokemon HeartGold/Pokemon SoulSilver     Nintendo  2009  Action
# 40    41                     Grand Theft Auto IV         XBox  2008  Action
# 44    45                     Grand Theft Auto IV  PlayStation  2008  Action
# 64    65                          FIFA Soccer 13  PlayStation  2012  Action
# 69    70  Grand Theft Auto: Liberty City Stories  PlayStation  2005  Action
# 76    77  The Legend of Zelda: Twilight Princess     Nintendo  2006  Action
# 89    90          Uncharted 3: Drake's Deception  PlayStation  2011  Action
# 92    93              Uncharted 2: Among Thieves  PlayStation  2009  Action
# 96    97                     Red Dead Redemption  PlayStation  2010  Action
#
#                       Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 11         Take-Two Interactive      7.01      9.27      0.97         4.14
# 12         Take-Two Interactive      9.43      0.40      0.41        10.57
# 15         Take-Two Interactive      9.63      5.31      0.06         1.38
# 16         Take-Two Interactive      8.41      5.49      0.47         1.78
# 29         Take-Two Interactive      6.99      4.51      0.30         1.30
# 35         Take-Two Interactive      3.80      5.81      0.36         2.02
# 36                     Nintendo      4.40      2.77      3.96         0.77
# 40         Take-Two Interactive      6.76      3.10      0.14         1.03
# 44         Take-Two Interactive      4.76      3.76      0.44         1.62
# 64              Electronic Arts      1.06      5.05      0.13         2.01
# 69         Take-Two Interactive      2.90      2.83      0.24         1.75
# 76                     Nintendo      3.83      2.19      0.60         0.70
# 89  Sony Computer Entertainment      2.77      2.80      0.19         1.06
# 92  Sony Computer Entertainment      3.27      2.25      0.21         1.00
# 96         Take-Two Interactive      2.79      2.61      0.17         1.03
#
#     Global_Sales
# 11         21.40
# 12         20.81
# 15         16.38
# 16         16.15
# 29         13.10
# 35         11.98
# 36         11.90
# 40         11.02
# 44         10.57
# 64          8.24
# 69          7.72
# 76          7.31
# 89          6.83
# 92          6.73
# 96          6.60
