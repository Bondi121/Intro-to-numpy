# %%
import sys
# !{sys.executable} -m pip install --upgrade pip
# !{sys.executable} -m pip install msgpack
# !{sys.executable} -m pip install matplotlib
# %matplotlib inline
# Out:
# Requirement already satisfied: pip in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (23.0.1)
# Requirement already satisfied: msgpack in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (1.0.4)
# Requirement already satisfied: matplotlib in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (3.6.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (22.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: numpy>=1.19 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from matplotlib) (9.3.0)
# Requirement already satisfied: six>=1.5 in c:\users\gabri\miniconda3\envs\100days\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib.pyplot as plt

plt.plot([1,2,3,4], [1,4,9,16], color='green', linestyle='dashdot', label='dash-dot')
plt.plot([2,3,4,5], [2,3,4,5], color='#2B5B84', linestyle='dashed', label='dashed')
plt.ylabel('Important Figures')
plt.legend()
plt.show()

# %%
panel_1 = plt.subplot(2,1,1)
plt.plot([1,2,3,4], [1,4,9,16], color='green', linestyle='dashdot')
panel_1.set_xlim([0,6])
panel_1.set_ylim([0,20])

panel_2 = plt.subplot(2,1,2)
plt.plot([2,3,4,5], [2,3,4,5], color='#2B5B84', linestyle='dashed')
panel_2.set_xlim([0,6])
panel_2.set_ylim([0,20])

plt.show()
