# %%
import seaborn as sns
import pandas as pd

sns.set_theme()

pokemon = pd.read_csv('pokemon_40.csv')
pokemon.head()
# Out:
#         Name      Type  HP  Attack  Defense
# 0  Marshtomp     Water  70      85       70
# 1  Carnivine     Grass  74     100       72
# 2  Magnemite  Electric  25      35       70
# 3     Amaura      Rock  77      59       50
# 4    Marowak    Ground  60      80      110

# %%
scatter_fig = sns.scatterplot(data=pokemon, x='HP', y='Attack', hue='Type')
scatter_fig.savefig('scatterplot.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[5], line 2
#       1 scatter_fig = sns.scatterplot(data=pokemon, x='HP', y='Attack', hue='Type')
# ----> 2 scatter_fig.savefig('scatterplot.png')
#
# AttributeError: 'AxesSubplot' object has no attribute 'savefig'
